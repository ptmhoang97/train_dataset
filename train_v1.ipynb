# %% [markdown]
# # 0. Setup Paths

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# %%
CUSTOM_MODEL_NAME = 'my_ssd_mobnet' 
PRETRAINED_MODEL_NAME = 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8'
PRETRAINED_MODEL_URL = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz'
TF_RECORD_SCRIPT_NAME = 'generate_tfrecord.py'
LABEL_MAP_NAME = 'label_map.pbtxt'

# %%
paths = {
    'WORKSPACE_PATH': os.path.join('Tensorflow', 'workspace'),
    'SCRIPTS_PATH': os.path.join('Tensorflow','scripts'),
    'APIMODEL_PATH': os.path.join('Tensorflow','models'),
    'ANNOTATION_PATH': os.path.join('Tensorflow', 'workspace','annotations'),
    'IMAGE_PATH': os.path.join('Tensorflow', 'workspace','images'),
    'MODEL_PATH': os.path.join('Tensorflow', 'workspace','models'),
    'PRETRAINED_MODEL_PATH': os.path.join('Tensorflow', 'workspace','pre-trained-models'),
    'CHECKPOINT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME), 
    'OUTPUT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'export'), 
    'TFJS_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfjsexport'), 
    'TFLITE_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfliteexport'), 
    'PROTOC_PATH':os.path.join('Tensorflow','protoc')
 }

# %%
files = {
    'PIPELINE_CONFIG':os.path.join('Tensorflow', 'workspace','models', CUSTOM_MODEL_NAME, 'pipeline.config'),
    'TF_RECORD_SCRIPT': os.path.join(paths['SCRIPTS_PATH'], TF_RECORD_SCRIPT_NAME), 
    'LABELMAP': os.path.join(paths['ANNOTATION_PATH'], LABEL_MAP_NAME)
}

# %%
for path in paths.values():
    if not os.path.exists(path):
        if os.name == 'posix':
            # !mkdir -p {path}
        if os.name == 'nt':
            # !mkdir {path}

# %%
# !unrar x /content/drive/MyDrive/car_coco_2017.rar -d /content/Tensorflow/workspace/images

# %% [markdown]
# # 1. Download TF Models Pretrained Models from Tensorflow Model Zoo and Install TFOD

# %%
# https://www.tensorflow.org/install/source_windows

# %%
if os.name=='nt':
    # !pip install wget
    import wget

# %%
if not os.path.exists(os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection')):
    # !git clone https://github.com/tensorflow/models {paths['APIMODEL_PATH']}
# Out:
# Cloning into 'Tensorflow/models'...
# remote: Enumerating objects: 60755, done.
# remote: Counting objects: 100% (534/534), done.
# remote: Compressing objects: 100% (311/311), done.
# remote: Total 60755 (delta 306), reused 421 (delta 206), pack-reused 60221
# Receiving objects: 100% (60755/60755), 574.04 MiB | 27.24 MiB/s, done.
# Resolving deltas: 100% (42198/42198), done.

# %%
# Install Tensorflow Object Detection 
if os.name=='posix':  
    # !apt-get install protobuf-compiler
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && cp object_detection/packages/tf2/setup.py . && python -m pip install . 
    
if os.name=='nt':
    url="https://github.com/protocolbuffers/protobuf/releases/download/v3.15.6/protoc-3.15.6-win64.zip"
    wget.download(url)
    # !move protoc-3.15.6-win64.zip {paths['PROTOC_PATH']}
    # !cd {paths['PROTOC_PATH']} && tar -xf protoc-3.15.6-win64.zip
    os.environ['PATH'] += os.pathsep + os.path.abspath(os.path.join(paths['PROTOC_PATH'], 'bin'))   
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && copy object_detection\\packages\\tf2\\setup.py setup.py && python setup.py build && python setup.py install
    # !cd Tensorflow/models/research/slim && pip install -e .
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# protobuf-compiler is already the newest version (3.0.0-9.1ubuntu1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 40 not upgraded.
# Processing /content/Tensorflow/models/research
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# Collecting avro-python3
#   Downloading avro-python3-1.10.2.tar.gz (38 kB)
# Collecting apache-beam
#   Downloading apache_beam-2.32.0-cp37-cp37m-manylinux2010_x86_64.whl (9.8 MB)
#      |████████████████████████████████| 9.8 MB 17.3 MB/s
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (7.1.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (4.2.6)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (3.2.2)
# Requirement already satisfied: Cython in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (0.29.24)
# Requirement already satisfied: contextlib2 in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (0.5.5)
# Collecting tf-slim
#   Downloading tf_slim-1.1.0-py2.py3-none-any.whl (352 kB)
#      |████████████████████████████████| 352 kB 15.9 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (1.15.0)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (2.0.2)
# Collecting lvis
#   Downloading lvis-0.5.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (1.4.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (1.1.5)
# Collecting tf-models-official>=2.5.1
#   Downloading tf_models_official-2.6.0-py2.py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 37.1 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 36.7 MB/s
# Requirement already satisfied: google-api-python-client>=1.6.7 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.12.8)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.19.5)
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      |████████████████████████████████| 43 kB 2.0 MB/s
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 31.0 MB/s
# Requirement already satisfied: gin-config in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.4.0)
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 9.9 MB/s
# Collecting tensorflow-text>=2.5.0
#   Downloading tensorflow_text-2.6.0-cp37-cp37m-manylinux1_x86_64.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 20.5 MB/s
# Requirement already satisfied: tensorflow>=2.5.0 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.6.0)
# Collecting opencv-python-headless
#   Downloading opencv_python_headless-4.5.3.56-cp37-cp37m-manylinux2014_x86_64.whl (37.1 MB)
#      |████████████████████████████████| 37.1 MB 47 kB/s
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.0.1)
# Requirement already satisfied: psutil>=5.4.3 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (5.4.8)
# Collecting py-cpuinfo>=3.3.0
#   Downloading py-cpuinfo-8.0.0.tar.gz (99 kB)
#      |████████████████████████████████| 99 kB 8.3 MB/s
# Collecting tensorflow-model-optimization>=0.4.1
#   Downloading tensorflow_model_optimization-0.6.0-py2.py3-none-any.whl (211 kB)
#      |████████████████████████████████| 211 kB 46.6 MB/s
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.14.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 33.7 MB/s
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.12.0)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.1.3)
# Requirement already satisfied: kaggle>=1.3.9 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.5.12)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (3.0.1)
# Requirement already satisfied: google-auth>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.34.0)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.17.4)
# Requirement already satisfied: google-api-core<2dev,>=1.21.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.26.3)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.0.4)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (3.17.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2018.9)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.53.0)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (21.0)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (57.4.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.23.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.2.2)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (5.0.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2.8.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.24.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2021.5.30)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (4.62.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->google-api-core<2dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.4.7)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (3.0.4)
# Requirement already satisfied: clang~=5.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (5.0)
# Requirement already satisfied: tensorboard~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (2.6.0)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (0.37.0)
# Requirement already satisfied: grpcio<2.0,>=1.37.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (1.39.0)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (0.12.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (1.12)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (3.3.0)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (0.2.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (1.1.2)
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.0)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (1.12.1)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (3.7.4.3)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (1.6.3)
# Requirement already satisfied: keras~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (2.6.0)
# Requirement already satisfied: h5py~=3.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (3.1.0)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (1.1.0)
# Requirement already satisfied: tensorflow-estimator~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (2.6.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py~=3.1.0->tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (1.5.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.5)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (1.8.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (3.3.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (1.0.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (1.3.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (4.6.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (3.1.1)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official>=2.5.1->object-detection==0.1) (0.1.6)
# Collecting dill<0.3.2,>=0.3.1.1
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
#      |████████████████████████████████| 151 kB 48.2 MB/s
# Requirement already satisfied: crcmod<2.0,>=1.7 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (1.7)
# Collecting fastavro<2,>=0.21.4
#   Downloading fastavro-1.4.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 32.4 MB/s
# Collecting requests<3.0.0dev,>=2.18.0
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 842 kB/s
# Collecting orjson<4.0
#   Downloading orjson-3.6.3-cp37-cp37m-manylinux_2_24_x86_64.whl (234 kB)
#      |████████████████████████████████| 234 kB 51.2 MB/s
# Requirement already satisfied: pyarrow<5.0.0,>=0.15.1 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (3.0.0)
# Collecting future<1.0.0,>=0.18.2
#   Downloading future-0.18.2.tar.gz (829 kB)
#      |████████████████████████████████| 829 kB 32.3 MB/s
# Collecting avro-python3
#   Downloading avro-python3-1.9.2.1.tar.gz (37 kB)
# Collecting hdfs<3.0.0,>=2.1.0
#   Downloading hdfs-2.6.0-py3-none-any.whl (33 kB)
# Requirement already satisfied: pymongo<4.0.0,>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (3.12.0)
# Requirement already satisfied: pydot<2,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (1.3.0)
# Requirement already satisfied: docopt in /usr/local/lib/python3.7/dist-packages (from hdfs<3.0.0,>=2.1.0->apache-beam->object-detection==0.1) (0.6.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.0.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard~=2.6->tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (3.5.0)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from lvis->object-detection==0.1) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from lvis->object-detection==0.1) (1.3.1)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /usr/local/lib/python3.7/dist-packages (from lvis->object-detection==0.1) (4.1.2.30)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.3)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu->tf-models-official>=2.5.1->object-detection==0.1) (0.8.9)
# Collecting portalocker
#   Downloading portalocker-2.3.1-py2.py3-none-any.whl (15 kB)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu->tf-models-official>=2.5.1->object-detection==0.1) (2019.12.20)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.7/dist-packages (from seqeval->tf-models-official>=2.5.1->object-detection==0.1) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.0.1)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons->tf-models-official>=2.5.1->object-detection==0.1) (2.7.1)
# Requirement already satisfied: attrs>=18.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (21.2.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (5.2.2)
# Requirement already satisfied: promise in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (2.3)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (1.2.0)
# Building wheels for collected packages: object-detection, py-cpuinfo, avro-python3, dill, future, seqeval
#   Building wheel for object-detection (setup.py) ... done
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1661032 sha256=fd167204302672d8811cc6dd76fc336a1e1094ec061757e33f03c57618051895
#   Stored in directory: /tmp/pip-ephem-wheel-cache-lrb3qxm3/wheels/a9/26/bf/1cb2313ed4855917889b97658bf0a19999e3588e47867bdaee
#   Building wheel for py-cpuinfo (setup.py) ... done
#   Created wheel for py-cpuinfo: filename=py_cpuinfo-8.0.0-py3-none-any.whl size=22258 sha256=522a0b32a08dd5dc2c4ada4c52a1d9b27d3b0503ffa768eb49fbf571ef765242
#   Stored in directory: /root/.cache/pip/wheels/d2/f1/1f/041add21dc9c4220157f1bd2bd6afe1f1a49524c3396b94401
#   Building wheel for avro-python3 (setup.py) ... done
#   Created wheel for avro-python3: filename=avro_python3-1.9.2.1-py3-none-any.whl size=43512 sha256=c1e747fc64d39b34e27ad58a7dfe822b288551728fc9960e6c1469fad7b50650
#   Stored in directory: /root/.cache/pip/wheels/bc/49/5f/fdb5b9d85055c478213e0158ac122b596816149a02d82e0ab1
#   Building wheel for dill (setup.py) ... done
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78546 sha256=c9291a7a95079afcb26877c7757e0b7133fb6914a2643c89e2171357ae48bc20
#   Stored in directory: /root/.cache/pip/wheels/a4/61/fd/c57e374e580aa78a45ed78d5859b3a44436af17e22ca53284f
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=5c150abf585b885d2b40c98b5bd0709b6db1a709ac069244147184e420c0ca52
#   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16181 sha256=3c6dbc60b39c42c286a8fb29aa43bb5e2b99a695cef8cd52304fd58ad644f8f8
#   Stored in directory: /root/.cache/pip/wheels/05/96/ee/7cac4e74f3b19e3158dce26a20a1c86b3533c43ec72a549fd7
# Successfully built object-detection py-cpuinfo avro-python3 dill future seqeval
# Installing collected packages: requests, portalocker, future, dill, colorama, tf-slim, tensorflow-text, tensorflow-model-optimization, tensorflow-addons, seqeval, sentencepiece, sacrebleu, pyyaml, py-cpuinfo, orjson, opencv-python-headless, hdfs, fastavro, avro-python3, tf-models-official, lvis, apache-beam, object-detection
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: future
#     Found existing installation: future 0.16.0
#     Uninstalling future-0.16.0:
#       Successfully uninstalled future-0.16.0
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.4
#     Uninstalling dill-0.3.4:
#       Successfully uninstalled dill-0.3.4
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# multiprocess 0.70.12.2 requires dill>=0.3.4, but you have dill 0.3.1.1 which is incompatible.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.26.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed apache-beam-2.32.0 avro-python3-1.9.2.1 colorama-0.4.4 dill-0.3.1.1 fastavro-1.4.4 future-0.18.2 hdfs-2.6.0 lvis-0.5.3 object-detection-0.1 opencv-python-headless-4.5.3.56 orjson-3.6.3 portalocker-2.3.1 py-cpuinfo-8.0.0 pyyaml-5.4.1 requests-2.26.0 sacrebleu-2.0.0 sentencepiece-0.1.96 seqeval-1.2.2 tensorflow-addons-0.14.0 tensorflow-model-optimization-0.6.0 tensorflow-text-2.6.0 tf-models-official-2.6.0 tf-slim-1.1.0

# %%
VERIFICATION_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'builders', 'model_builder_tf2_test.py')
# Verify Installation
# !python {VERIFICATION_SCRIPT}
# Out:
# 2021-08-26 09:56:03.468158: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-26 09:56:04.096637: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-26 09:56:04.097477: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# Running tests under Python 3.7.11: /usr/bin/python3
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# 2021-08-26 09:56:04.157453: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-26 09:56:04.158370: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-26 09:56:04.159146: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-26 09:56:09.202108: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-26 09:56:09.202982: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-26 09:56:09.203717: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-26 09:56:09.204632: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-08-26 09:56:09.205613: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10819 MB memory:  -> device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7
# W0826 09:56:09.597550 140028557662080 model_builder.py:1088] Building experimental DeepMAC meta-arch. Some features may be omitted.
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 5.91s
# I0826 09:56:10.011219 140028557662080 test_util.py:2189] time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 5.91s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_deepmac
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.65s
# I0826 09:56:10.658068 140028557662080 test_util.py:2189] time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.65s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.34s
# I0826 09:56:10.993995 140028557662080 test_util.py:2189] time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.34s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.33s
# I0826 09:56:11.321012 140028557662080 test_util.py:2189] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.33s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# W0826 09:56:11.323640 140028557662080 mobilenet_v2.py:297] `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step
# 9420800/9406464 [==============================] - 0s 0us/step
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 2.7s
# I0826 09:56:14.023381 140028557662080 test_util.py:2189] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 2.7s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# [ RUN      ] ModelBuilderTF2Test.test_create_experimental_model
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# I0826 09:56:14.024544 140028557662080 test_util.py:2189] time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# [       OK ] ModelBuilderTF2Test.test_create_experimental_model
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.03s
# I0826 09:56:14.052758 140028557662080 test_util.py:2189] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.03s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.02s
# I0826 09:56:14.070242 140028557662080 test_util.py:2189] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.02s
# I0826 09:56:14.088773 140028557662080 test_util.py:2189] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.13s
# I0826 09:56:14.214492 140028557662080 test_util.py:2189] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.13s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.12s
# I0826 09:56:14.333428 140028557662080 test_util.py:2189] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.12s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.12s
# I0826 09:56:14.455441 140028557662080 test_util.py:2189] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.12s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.12s
# I0826 09:56:14.577845 140028557662080 test_util.py:2189] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.12s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.13s
# I0826 09:56:14.710110 140028557662080 test_util.py:2189] time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.13s
# [       OK ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.03s
# I0826 09:56:14.745564 140028557662080 test_util.py:2189] time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.03s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# I0826 09:56:15.102612 140028557662080 ssd_efficientnet_bifpn_feature_extractor.py:143] EfficientDet EfficientNet backbone version: efficientnet-b0
# I
per-step time 0.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.7304645,
#  'Loss/localization_loss': 0.83384293,
#  'Loss/regularization_loss': 0.16316429,
#  'Loss/total_loss': 1.7274717,
#  'learning_rate': 0.053333}
# I0826 10:07:24.861476 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.7304645,
#  'Loss/localization_loss': 0.83384293,
#  'Loss/regularization_loss': 0.16316429,
#  'Loss/total_loss': 1.7274717,
#  'learning_rate': 0.053333}
# INFO:tensorflow:Step 600 per-step time 0.192s
# I0826 10:07:44.081350 140418409645952 model_lib_v2.py:700] Step 600 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.8121689,
#  'Loss/localization_loss': 0.6301986,
#  'Loss/regularization_loss': 0.16280238,
#  'Loss/total_loss': 1.6051699,
#  'learning_rate': 0.0586664}
# I0826 10:07:44.081709 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.8121689,
#  'Loss/localization_loss': 0.6301986,
#  'Loss/regularization_loss': 0.16280238,
#  'Loss/total_loss': 1.6051699,
#  'learning_rate': 0.0586664}
# INFO:tensorflow:Step 700 per-step time 0.192s
# I0826 10:08:03.223726 140418409645952 model_lib_v2.py:700] Step 700 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.67812055,
#  'Loss/localization_loss': 0.8388974,
#  'Loss/regularization_loss': 0.16227394,
#  'Loss/total_loss': 1.679292,
#  'learning_rate': 0.0639998}
# I0826 10:08:03.224069 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.67812055,
#  'Loss/localization_loss': 0.8388974,
#  'Loss/regularization_loss': 0.16227394,
#  'Loss/total_loss': 1.679292,
#  'learning_rate': 0.0639998}
# INFO:tensorflow:Step 800 per-step time 0.193s
# I0826 10:08:22.559875 140418409645952 model_lib_v2.py:700] Step 800 per-step time 0.193s
# INFO:tensorflow:{'Loss/classification_loss': 0.6210928,
#  'Loss/localization_loss': 0.62450576,
#  'Loss/regularization_loss': 0.16219348,
#  'Loss/total_loss': 1.4077921,
#  'learning_rate': 0.069333196}
# I0826 10:08:22.560217 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.6210928,
#  'Loss/localization_loss': 0.62450576,
#  'Loss/regularization_loss': 0.16219348,
#  'Loss/total_loss': 1.4077921,
#  'learning_rate': 0.069333196}
# INFO:tensorflow:Step 900 per-step time 0.193s
# I0826 10:08:41.831968 140418409645952 model_lib_v2.py:700] Step 900 per-step time 0.193s
# INFO:tensorflow:{'Loss/classification_loss': 0.56882584,
#  'Loss/localization_loss': 0.72103,
#  'Loss/regularization_loss': 0.16188942,
#  'Loss/total_loss': 1.4517453,
#  'learning_rate': 0.074666604}
# I0826 10:08:41.832368 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.56882584,
#  'Loss/localization_loss': 0.72103,
#  'Loss/regularization_loss': 0.16188942,
#  'Loss/total_loss': 1.4517453,
#  'learning_rate': 0.074666604}
# INFO:tensorflow:Step 1000 per-step time 0.193s
# I0826 10:09:01.123689 140418409645952 model_lib_v2.py:700] Step 1000 per-step time 0.193s
# INFO:tensorflow:{'Loss/classification_loss': 0.6686493,
#  'Loss/localization_loss': 0.7044396,
#  'Loss/regularization_loss': 0.16148336,
#  'Loss/total_loss': 1.5345722,
#  'learning_rate': 0.08}
# I0826 10:09:01.124137 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.6686493,
#  'Loss/localization_loss': 0.7044396,
#  'Loss/regularization_loss': 0.16148336,
#  'Loss/total_loss': 1.5345722,
#  'learning_rate': 0.08}
# INFO:tensorflow:Step 1100 per-step time 0.198s
# I0826 10:09:20.937695 140418409645952 model_lib_v2.py:700] Step 1100 per-step time 0.198s
# INFO:tensorflow:{'Loss/classification_loss': 0.5030176,
#  'Loss/localization_loss': 0.5422029,
#  'Loss/regularization_loss': 0.16108255,
#  'Loss/total_loss': 1.206303,
#  'learning_rate': 0.07999918}
# I0826 10:09:20.938115 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.5030176,
#  'Loss/localization_loss': 0.5422029,
#  'Loss/regularization_loss': 0.16108255,
#  'Loss/total_loss': 1.206303,
#  'learning_rate': 0.07999918}
# INFO:tensorflow:Step 1200 per-step time 0.193s
# I0826 10:09:40.203221 140418409645952 model_lib_v2.py:700] Step 1200 per-step time 0.193s
# INFO:tensorflow:{'Loss/classification_loss': 0.6152138,
#  'Loss/localization_loss': 0.7376747,
#  'Loss/regularization_loss': 0.16063786,
#  'Loss/total_loss': 1.5135264,
#  'learning_rate': 0.079996705}
# I0826 10:09:40.203589 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.6152138,
#  'Loss/localization_loss': 0.7376747,
#  'Loss/regularization_loss': 0.16063786,
#  'Loss/total_loss': 1.5135264,
#  'learning_rate': 0.079996705}
# INFO:tensorflow:Step 1300 per-step time 0.191s
# I0826 10:09:59.354544 140418409645952 model_lib_v2.py:700] Step 1300 per-step time 0.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.5544493,
#  'Loss/localization_loss': 0.64378744,
#  'Loss/regularization_loss': 0.16019323,
#  'Loss/total_loss': 1.3584299,
#  'learning_rate': 0.0799926}
# I0826 10:09:59.354905 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.5544493,
#  'Loss/localization_loss': 0.64378744,
#  'Loss/regularization_loss': 0.16019323,
#  'Loss/total_loss': 1.3584299,
#  'learning_rate': 0.0799926}
# INFO:tensorflow:Step 1400 per-step time 0.192s
# I0826 10:10:18.548533 140418409645952 model_lib_v2.py:700] Step 1400 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.48384827,
#  'Loss/localization_loss': 0.66218764,
#  'Loss/regularization_loss': 0.15972294,
#  'Loss/total_loss': 1.3057588,
#  'learning_rate': 0.07998685}
# I0826 10:10:18.548943 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.48384827,
#  'Loss/localization_loss': 0.66218764,
#  'Loss/regularization_loss': 0.15972294,
#  'Loss/total_loss': 1.3057588,
#  'learning_rate': 0.07998685}
# INFO:tensorflow:Step 1500 per-step time 0.194s
# I0826 10:10:37.911981 140418409645952 model_lib_v2.py:700] Step 1500 per-step time 0.194s
# INFO:tensorflow:{'Loss/classification_loss': 0.5192979,
#  'Loss/localization_loss': 0.7409143,
#  'Loss/regularization_loss': 0.1594054,
#  'Loss/total_loss': 1.4196175,
#  'learning_rate': 0.07997945}
# I0826 10:10:37.912437 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.5192979,
#  'Loss/localization_loss': 0.7409143,
#  'Loss/regularization_loss': 0.1594054,
#  'Loss/total_loss': 1.4196175,
#  'learning_rate': 0.07997945}
# INFO:tensorflow:Step 1600 per-step time 0.192s
# I0826 10:10:57.108364 140418409645952 model_lib_v2.py:700] Step 1600 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.5682506,
#  'Loss/localization_loss': 0.35869342,
#  'Loss/regularization_loss': 0.15911423,
#  'Loss/total_loss': 1.0860583,
#  'learning_rate': 0.079970405}
# I0826 10:10:57.108769 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.5682506,
#  'Loss/localization_loss': 0.35869342,
#  'Loss/regularization_loss': 0.15911423,
#  'Loss/total_loss': 1.0860583,
#  'learning_rate': 0.079970405}
# INFO:tensorflow:Step 1700 per-step time 0.192s
# I0826 10:11:16.285597 140418409645952 model_lib_v2.py:700] Step 1700 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.6570994,
#  'Loss/localization_loss': 0.5668813,
#  'Loss/regularization_loss': 0.15878901,
#  'Loss/total_loss': 1.3827697,
#  'learning_rate': 0.07995972}
# I0826 10:11:16.286135 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.6570994,
#  'Loss/localization_loss': 0.5668813,
#  'Loss/regularization_loss': 0.15878901,
#  'Loss/total_loss': 1.3827697,
#  'learning_rate': 0.07995972}
# INFO:tensorflow:Step 1800 per-step time 0.192s
# I0826 10:11:35.466939 140418409645952 model_lib_v2.py:700] Step 1800 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.47575998,
#  'Loss/localization_loss': 0.28168628,
#  'Loss/regularization_loss': 0.15850313,
#  'Loss/total_loss': 0.9159494,
#  'learning_rate': 0.0799474}
# I0826 10:11:35.467367 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.47575998,
#  'Loss/localization_loss': 0.28168628,
#  'Loss/regularization_loss': 0.15850313,
#  'Loss/total_loss': 0.9159494,
#  'learning_rate': 0.0799474}
# INFO:tensorflow:Step 1900 per-step time 0.192s
# I0826 10:11:54.673681 140418409645952 model_lib_v2.py:700] Step 1900 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.4165763,
#  'Loss/localization_loss': 0.51201606,
#  'Loss/regularization_loss': 0.15819766,
#  'Loss/total_loss': 1.08679,
#  'learning_rate': 0.07993342}
# I0826 10:11:54.674107 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.4165763,
#  'Loss/localization_loss': 0.51201606,
#  'Loss/regularization_loss': 0.15819766,
#  'Loss/total_loss': 1.08679,
#  'learning_rate': 0.07993342}
# INFO:tensorflow:Step 2000 per-step time 0.193s
# I0826 10:12:13.952204 140418409645952 model_lib_v2.py:700] Step 2000 per-step time 0.193s
# INFO:tensorflow:{'Loss/classification_loss': 0.5182131,
#  'Loss/localization_loss': 0.4801978,
#  'Loss/regularization_loss': 0.15785015,
#  'Loss/total_loss': 1.156261,
#  'learning_rate': 0.07991781}
# I0826 10:12:13.952674 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.5182131,
#  'Loss/localization_loss': 0.4801978,
#  'Loss/regularization_loss': 0.15785015,
#  'Loss/total_loss': 1.156261,
#  'learning_rate': 0.07991781}
# INFO:tensorflow:Step 2100 per-step time 0.198s
# I0826 10:12:33.722792 140418409645952 model_lib_v2.py:700] Step 2100 per-step time 0.198s
# INFO:tensorflow:{'Loss/classification_loss': 0.50057256,
#  'Loss/localization_loss': 0.56207305,
#  'Loss/regularization_loss': 0.15758806,
#  'Loss/total_loss': 1.2202337,
#  'learning_rate': 0.07990056}
# I0826 10:12:33.723165 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.50057256,
#  'Loss/localization_loss': 0.56207305,
#  'Loss/regularization_loss': 0.15758806,
#  'Loss/total_loss': 1.2202337,
#  'learning_rate': 0.07990056}
# INFO:tensorflow:Step 2200 per-step time 0.193s
# I0826 10:12:53.048331 140418409645952 model_lib_v2.py:700] Step 2200 per-step time 0.193s
# INFO:tensorflow:{'Loss/classification_loss': 0.4810781,
#  'Loss/localization_loss': 0.47856033,
#  'Loss/regularization_loss': 0.15743536,
#  'Loss/total_loss': 1.1170738,
#  'learning_rate': 0.07988167}
# I0826 10:12:53.048694 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.4810781,
#  'Loss/localization_loss': 0.47856033,
#  'Loss/regularization_loss': 0.15743536,
#  'Loss/total_loss': 1.1170738,
#  'learning_rate': 0.07988167}
# INFO:tensorflow:Step 2300 per-step time 0.192s
# I0826 10:13:12.247971 140418409645952 model_lib_v2.py:700] Step 2300 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.8842849,
#  'Loss/localization_loss': 0.7718138,
#  'Loss/regularization_loss': 0.15703583,
#  'Loss/total_loss': 1.8131346,
#  'learning_rate': 0.07986114}
# I0826 10:13:12.248320 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.8842849,
#  'Loss/localization_loss': 0.7718138,
#  'Loss/regularization_loss': 0.15703583,
#  'Loss/total_loss': 1.8131346,
#  'learning_rate': 0.07986114}
# INFO:tensorflow:Step 2400 per-step time 0.193s
# I0826 10:13:31.543514 140418409645952 model_lib_v2.py:700] Step 2400 per-step time 0.193s
# INFO:tensorflow:{'Loss/classification_loss': 0.5216249,
#  'Loss/localization_loss': 0.5820288,
#  'Loss/regularization_loss': 0.15666462,
#  'Loss/total_loss': 1.2603183,
#  'learning_rate': 0.07983897}
# I0826 10:13:31.543916 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.5216249,
#  'Loss/localization_loss': 0.5820288,
#  'Loss/regularization_loss': 0.15666462,
#  'Loss/total_loss': 1.2603183,
#  'learning_rate': 0.07983897}
# INFO:tensorflow:Step 2500 per-step time 0.193s
# I0826 10:13:50.799128 140418409645952 model_lib_v2.py:700] Step 2500 per-step time 0.193s
# INFO:tensorflow:{'Loss/classification_loss': 0.42334488,
#  'Loss/localization_loss': 0.45776728,
#  'Loss/regularization_loss': 0.15641089,
#  'Loss/total_loss': 1.037523,
#  'learning_rate': 0.079815164}
# I0826 10:13:50.799545 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.42334488,
#  'Loss/localization_loss': 0.45776728,
#  'Loss/regularization_loss': 0.15641089,
#  'Loss/total_loss': 1.037523,
#  'learning_rate': 0.079815164}
# INFO:tensorflow:Step 2600 per-step time 0.192s
# I0826 10:14:09.980405 140418409645952 model_lib_v2.py:700] Step 2600 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.58581954,
#  'Loss/localization_loss': 0.61746615,
#  'Loss/regularization_loss': 0.15621322,
#  'Loss/total_loss': 1.359499,
#  'learning_rate': 0.07978972}
# I0826 10:14:09.980755 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.58581954,
#  'Loss/localization_loss': 0.61746615,
#  'Loss/regularization_loss': 0.15621322,
#  'Loss/total_loss': 1.359499,
#  'learning_rate': 0.07978972}
# INFO:tensorflow:Step 2700 per-step time 0.193s
# I0826 10:14:29.278380 140418409645952 model_lib_v2.py:700] Step 2700 per-step time 0.193s
# INFO:tensorflow:{'Loss/classification_loss': 0.5271271,
#  'Loss/localization_loss': 0.8297054,
#  'Loss/regularization_loss': 0.15590082,
#  'Loss/total_loss': 1.5127333,
#  'learning_rate': 0.07976264}
# I0826 10:14:29.278773 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.5271271,
#  'Loss/localization_loss': 0.8297054,
#  'Loss/regularization_loss': 0.15590082,
#  'Loss/total_loss': 1.5127333,
#  'learning_rate': 0.07976264}
# INFO:tensorflow:Step 2800 per-step time 0.192s
# I0826 10:14:48.477448 140418409645952 model_lib_v2.py:700] Step 2800 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.38284153,
#  'Loss/localization_loss': 0.42104265,
#  'Loss/regularization_loss': 0.15552647,
#  'Loss/total_loss': 0.9594106,
#  'learning_rate': 0.07973392}
# I0826 10:14:48.477777 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.38284153,
#  'Loss/localization_loss': 0.42104265,
#  'Loss/regularization_loss': 0.15552647,
#  'Loss/total_loss': 0.9594106,
#  'learning_rate': 0.07973392}
# INFO:tensorflow:Step 2900 per-step time 0.191s
# I0826 10:15:07.569631 140418409645952 model_lib_v2.py:700] Step 2900 per-step time 0.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.4661701,
#  'Loss/localization_loss': 0.521142,
#  'Loss/regularization_loss': 0.15513176,
#  'Loss/total_loss': 1.1424439,
#  'learning_rate': 0.07970358}
# I0826 10:15:07.570045 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.4661701,
#  'Loss/localization_loss': 0.521142,
#  'Loss/regularization_loss': 0.15513176,
#  'Loss/total_loss': 1.1424439,
#  'learning_rate': 0.07970358}
# INFO:tensorflow:Step 3000 per-step time 0.192s
# I0826 10:15:26.817611 140418409645952 model_lib_v2.py:700] Step 3000 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.5658659,
#  'Loss/localization_loss': 0.8155579,
#  'Loss/regularization_loss': 0.15486759,
#  'Loss/total_loss': 1.5362914,
#  'learning_rate': 0.0796716}
# I0826 10:15:26.817975 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.5658659,
#  'Loss/localization_loss': 0.8155579,
#  'Loss/regularization_loss': 0.15486759,
#  'Loss/total_loss': 1.5362914,
#  'learning_rate': 0.0796716}
# INFO:tensorflow:Step 3100 per-step time 0.198s
# I0826 10:15:46.609203 140418409645952 model_lib_v2.py:700] Step 3100 per-step time 0.198s
# INFO:tensorflow:{'Loss/classification_loss': 0.42942458,
#  'Loss/localization_loss': 0.5617866,
#  'Loss/regularization_loss': 0.15472078,
#  'Loss/total_loss': 1.145932,
#  'learning_rate': 0.07963799}
# I0826 10:15:46.609555 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.42942458,
#  'Loss/localization_loss': 0.5617866,
#  'Loss/regularization_loss': 0.15472078,
#  'Loss/total_loss': 1.145932,
#  'learning_rate': 0.07963799}
# INFO:tensorflow:Step 3200 per-step time 0.192s
# I0826 10:16:05.778610 140418409645952 model_lib_v2.py:700] Step 3200 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.6917656,
#  'Loss/localization_loss': 0.8381039,
#  'Loss/regularization_loss': 0.15449886,
#  'Loss/total_loss': 1.6843684,
#  'learning_rate': 0.07960275}
# I0826 10:16:05.779083 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.6917656,
#  'Loss/localization_loss': 0.8381039,
#  'Loss/regularization_loss': 0.15449886,
#  'Loss/total_loss': 1.6843684,
#  'learning_rate': 0.07960275}
# INFO:tensorflow:Step 3300 per-step time 0.192s
# I0826 10:16:24.989752 140418409645952 model_lib_v2.py:700] Step 3300 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.89623755,
#  'Loss/localization_loss': 1.0109704,
#  'Loss/regularization_loss': 0.15441006,
#  'Loss/total_loss': 2.061618,
#  'learning_rate': 0.07956588}
# I0826 10:16:24.990154 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.89623755,
#  'Loss/localization_loss': 1.0109704,
#  'Loss/regularization_loss': 0.15441006,
#  'Loss/total_loss': 2.061618,
#  'learning_rate': 0.07956588}
# INFO:tensorflow:Step 3400 per-step time 0.193s
# I0826 10:16:44.244963 140418409645952 model_lib_v2.py:700] Step 3400 per-step time 0.193s
# INFO:tensorflow:{'Loss/classification_loss': 0.46343562,
#  'Loss/localization_loss': 0.41970903,
#  'Loss/regularization_loss': 0.15415813,
#  'Loss/total_loss': 1.0373027,
#  'learning_rate': 0.079527386}
# I0826 10:16:44.245314 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.46343562,
#  'Loss/localization_loss': 0.41970903,
#  'Loss/regularization_loss': 0.15415813,
#  'Loss/total_loss': 1.0373027,
#  'learning_rate': 0.079527386}
# INFO:tensorflow:Step 3500 per-step time 0.192s
# I0826 10:17:03.441447 140418409645952 model_lib_v2.py:700] Step 3500 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.44183424,
#  'Loss/localization_loss': 0.45421982,
#  'Loss/regularization_loss': 0.1540009,
#  'Loss/total_loss': 1.0500549,
#  'learning_rate': 0.07948727}
# I0826 10:17:03.441787 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.44183424,
#  'Loss/localization_loss': 0.45421982,
#  'Loss/regularization_loss': 0.1540009,
#  'Loss/total_loss': 1.0500549,
#  'learning_rate': 0.07948727}
# INFO:tensorflow:Step 3600 per-step time 0.193s
# I0826 10:17:22.744885 140418409645952 model_lib_v2.py:700] Step 3600 per-step time 0.193s
# INFO:tensorflow:{'Loss/classification_loss': 0.50230247,
#  'Loss/localization_loss': 0.6579429,
#  'Loss/regularization_loss': 0.15384279,
#  'Loss/total_loss': 1.3140882,
#  'learning_rate': 0.079445526}
# I0826 10:17:22.745268 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.50230247,
#  'Loss/localization_loss': 0.6579429,
#  'Loss/regularization_loss': 0.15384279,
#  'Loss/total_loss': 1.3140882,
#  'learning_rate': 0.079445526}
# INFO:tensorflow:Step 3700 per-step time 0.192s
# I0826 10:17:41.975476 140418409645952 model_lib_v2.py:700] Step 3700 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.6582328,
#  'Loss/localization_loss': 0.7630006,
#  'Loss/regularization_loss': 0.1535613,
#  'Loss/total_loss': 1.5747948,
#  'learning_rate': 0.07940216}
# I0826 10:17:41.975816 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.6582328,
#  'Loss/localization_loss': 0.7630006,
#  'Loss/regularization_loss': 0.1535613,
#  'Loss/total_loss': 1.5747948,
#  'learning_rate': 0.07940216}
# INFO:tensorflow:Step 3800 per-step time 0.193s
# I0826 10:18:01.244325 140418409645952 model_lib_v2.py:700] Step 3800 per-step time 0.193s
# INFO:tensorflow:{'Loss/classification_loss': 0.4984864,
#  'Loss/localization_loss': 0.5069934,
#  'Loss/regularization_loss': 0.15326935,
#  'Loss/total_loss': 1.1587491,
#  'learning_rate': 0.079357184}
# I0826 10:18:01.244693 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.4984864,
#  'Loss/localization_loss': 0.5069934,
#  'Loss/regularization_loss': 0.15326935,
#  'Loss/total_loss': 1.1587491,
#  'learning_rate': 0.079357184}
# INFO:tensorflow:Step 3900 per-step time 0.191s
# I0826 10:18:20.304643 140418409645952 model_lib_v2.py:700] Step 3900 per-step time 0.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.48270947,
#  'Loss/localization_loss': 0.47072032,
#  'Loss/regularization_loss': 0.15295589,
#  'Loss/total_loss': 1.1063857,
#  'learning_rate': 0.07931058}
# I0826 10:18:20.305029 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.48270947,
#  'Loss/localization_loss': 0.47072032,
#  'Loss/regularization_loss': 0.15295589,
#  'Loss/total_loss': 1.1063857,
#  'learning_rate': 0.07931058}
# INFO:tensorflow:Step 4000 per-step time 0.193s
# I0826 10:18:39.564134 140418409645952 model_lib_v2.py:700] Step 4000 per-step time 0.193s
# INFO:tensorflow:{'Loss/classification_loss': 0.4256076,
#  'Loss/localization_loss': 0.524923,
#  'Loss/regularization_loss': 0.15285015,
#  'Loss/total_loss': 1.1033808,
#  'learning_rate': 0.07926236}
# I0826 10:18:39.564466 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.4256076,
#  'Loss/localization_loss': 0.524923,
#  'Loss/regularization_loss': 0.15285015,
#  'Loss/total_loss': 1.1033808,
#  'learning_rate': 0.07926236}
# INFO:tensorflow:Step 4100 per-step time 0.197s
# I0826 10:18:59.225013 140418409645952 model_lib_v2.py:700] Step 4100 per-step time 0.197s
# INFO:tensorflow:{'Loss/classification_loss': 0.49679253,
#  'Loss/localization_loss': 0.5489172,
#  'Loss/regularization_loss': 0.15259206,
#  'Loss/total_loss': 1.1983018,
#  'learning_rate': 0.07921253}
# I0826 10:18:59.225394 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.49679253,
#  'Loss/localization_loss': 0.5489172,
#  'Loss/regularization_loss': 0.15259206,
#  'Loss/total_loss': 1.1983018,
#  'learning_rate': 0.07921253}
# INFO:tensorflow:Step 4200 per-step time 0.191s
# I0826 10:19:18.353430 140418409645952 model_lib_v2.py:700] Step 4200 per-step time 0.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.41864568,
#  'Loss/localization_loss': 0.33288297,
#  'Loss/regularization_loss': 0.15252514,
#  'Loss/total_loss': 0.90405375,
#  'learning_rate': 0.07916109}
# I0826 10:19:18.353801 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.41864568,
#  'Loss/localization_loss': 0.33288297,
#  'Loss/regularization_loss': 0.15252514,
#  'Loss/total_loss': 0.90405375,
#  'learning_rate': 0.07916109}
# INFO:tensorflow:Step 4300 per-step time 0.192s
# I0826 10:19:37.564860 140418409645952 model_lib_v2.py:700] Step 4300 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.40359747,
#  'Loss/localization_loss': 0.45498696,
#  'Loss/regularization_loss': 0.15234253,
#  'Loss/total_loss': 1.010927,
#  'learning_rate': 0.07910804}
# I0826 10:19:37.565226 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.40359747,
#  'Loss/localization_loss': 0.45498696,
#  'Loss/regularization_loss': 0.15234253,
#  'Loss/total_loss': 1.010927,
#  'learning_rate': 0.07910804}
# INFO:tensorflow:Step 4400 per-step time 0.192s
# I0826 10:19:56.780156 140418409645952 model_lib_v2.py:700] Step 4400 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.7801984,
#  'Loss/localization_loss': 0.47945884,
#  'Loss/regularization_loss': 0.15223038,
#  'Loss/total_loss': 1.4118876,
#  'learning_rate': 0.07905338}
# I0826 10:19:56.780544 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.7801984,
#  'Loss/localization_loss': 0.47945884,
#  'Loss/regularization_loss': 0.15223038,
#  'Loss/total_loss': 1.4118876,
#  'learning_rate': 0.07905338}
# INFO:tensorflow:Step 4500 per-step time 0.192s
# I0826 10:20:15.957931 140418409645952 model_lib_v2.py:700] Step 4500 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.6008788,
#  'Loss/localization_loss': 0.683142,
#  'Loss/regularization_loss': 0.15247153,
#  'Loss/total_loss': 1.4364923,
#  'learning_rate': 0.07899711}
# I0826 10:20:15.958290 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.6008788,
#  'Loss/localization_loss': 0.683142,
#  'Loss/regularization_loss': 0.15247153,
#  'Loss/total_loss': 1.4364923,
#  'learning_rate': 0.07899711}
# INFO:tensorflow:Step 4600 per-step time 0.192s
# I0826 10:20:35.166116 140418409645952 model_lib_v2.py:700] Step 4600 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 1.2835267,
#  'Loss/localization_loss': 1.1112524,
#  'Loss/regularization_loss': 0.15222399,
#  'Loss/total_loss': 2.5470033,
#  'learning_rate': 0.078939244}
# I0826 10:20:35.166506 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 1.2835267,
#  'Loss/localization_loss': 1.1112524,
#  'Loss/regularization_loss': 0.15222399,
#  'Loss/total_loss': 2.5470033,
#  'learning_rate': 0.078939244}
# INFO:tensorflow:Step 4700 per-step time 0.191s
# I0826 10:20:54.303263 140418409645952 model_lib_v2.py:700] Step 4700 per-step time 0.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.4656195,
#  'Loss/localization_loss': 0.43211028,
#  'Loss/regularization_loss': 0.15198913,
#  'Loss/total_loss': 1.0497189,
#  'learning_rate': 0.07887978}
# I0826 10:20:54.303636 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.4656195,
#  'Loss/localization_loss': 0.43211028,
#  'Loss/regularization_loss': 0.15198913,
#  'Loss/total_loss': 1.0497189,
#  'learning_rate': 0.07887978}
# INFO:tensorflow:Step 4800 per-step time 0.193s
# I0826 10:21:13.561853 140418409645952 model_lib_v2.py:700] Step 4800 per-step time 0.193s
# INFO:tensorflow:{'Loss/classification_loss': 0.594355,
#  'Loss/localization_loss': 0.40802297,
#  'Loss/regularization_loss': 0.15151258,
#  'Loss/total_loss': 1.1538906,
#  'learning_rate': 0.07881871}
# I0826 10:21:13.562277 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.594355,
#  'Loss/localization_loss': 0.40802297,
#  'Loss/regularization_loss': 0.15151258,
#  'Loss/total_loss': 1.1538906,
#  'learning_rate': 0.07881871}
# INFO:tensorflow:Step 4900 per-step time 0.191s
# I0826 10:21:32.621260 140418409645952 model_lib_v2.py:700] Step 4900 per-step time 0.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.52713096,
#  'Loss/localization_loss': 0.45524836,
#  'Loss/regularization_loss': 0.15150484,
#  'Loss/total_loss': 1.1338842,
#  'learning_rate': 0.07875605}
# I0826 10:21:32.621647 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.52713096,
#  'Loss/localization_loss': 0.45524836,
#  'Loss/regularization_loss': 0.15150484,
#  'Loss/total_loss': 1.1338842,
#  'learning_rate': 0.07875605}
# INFO:tensorflow:Step 5000 per-step time 0.193s
# I0826 10:21:51.869711 140418409645952 model_lib_v2.py:700] Step 5000 per-step time 0.193s
# INFO:tensorflow:{'Loss/classification_loss': 0.39001328,
#  'Loss/localization_loss': 0.35719892,
#  'Loss/regularization_loss': 0.15109138,
#  'Loss/total_loss': 0.89830357,
#  'learning_rate': 0.078691795}
# I0826 10:21:51.870118 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.39001328,
#  'Loss/localization_loss': 0.35719892,
#  'Loss/regularization_loss': 0.15109138,
#  'Loss/total_loss': 0.89830357,
#  'learning_rate': 0.078691795}
# INFO:tensorflow:Step 5100 per-step time 0.197s
# I0826 10:22:11.601601 140418409645952 model_lib_v2.py:700] Step 5100 per-step time 0.197s
# INFO:tensorflow:{'Loss/classification_loss': 0.7287992,
#  'Loss/localization_loss': 0.5422629,
#  'Loss/regularization_loss': 0.15072657,
#  'Loss/total_loss': 1.4217887,
#  'learning_rate': 0.07862595}
# I0826 10:22:11.602157 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.7287992,
#  'Loss/localization_loss': 0.5422629,
#  'Loss/regularization_loss': 0.15072657,
#  'Loss/total_loss': 1.4217887,
#  'learning_rate': 0.07862595}
# INFO:tensorflow:Step 5200 per-step time 0.192s
# I0826 10:22:30.814889 140418409645952 model_lib_v2.py:700] Step 5200 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.5914424,
#  'Loss/localization_loss': 0.64088476,
#  'Loss/regularization_loss': 0.15050939,
#  'Loss/total_loss': 1.3828366,
#  'learning_rate': 0.07855851}
# I0826 10:22:30.815275 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.5914424,
#  'Loss/localization_loss': 0.64088476,
#  'Loss/regularization_loss': 0.15050939,
#  'Loss/total_loss': 1.3828366,
#  'learning_rate': 0.07855851}
# INFO:tensorflow:Step 5300 per-step time 0.193s
# I0826 10:22:50.128604 140418409645952 model_lib_v2.py:700] Step 5300 per-step time 0.193s
# INFO:tensorflow:{'Loss/classification_loss': 0.3690251,
#  'Loss/localization_loss': 0.47719744,
#  'Loss/regularization_loss': 0.15018456,
#  'Loss/total_loss': 0.9964071,
#  'learning_rate': 0.07848949}
# I0826 10:22:50.129026 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.3690251,
#  'Loss/localization_loss': 0.47719744,
#  'Loss/regularization_loss': 0.15018456,
#  'Loss/total_loss': 0.9964071,
#  'learning_rate': 0.07848949}
# INFO:tensorflow:Step 5400 per-step time 0.192s
# I0826 10:23:09.295899 140418409645952 model_lib_v2.py:700] Step 5400 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.4851483,
#  'Loss/localization_loss': 0.4683351,
#  'Loss/regularization_loss': 0.1498389,
#  'Loss/total_loss': 1.1033223,
#  'learning_rate': 0.078418896}
# I0826 10:23:09.296299 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.4851483,
#  'Loss/localization_loss': 0.4683351,
#  'Loss/regularization_loss': 0.1498389,
#  'Loss/total_loss': 1.1033223,
#  'learning_rate': 0.078418896}
# INFO:tensorflow:Step 5500 per-step time 0.193s
# I0826 10:23:28.565035 140418409645952 model_lib_v2.py:700] Step 5500 per-step time 0.193s
# INFO:tensorflow:{'Loss/classification_loss': 0.51591974,
#  'Loss/localization_loss': 0.5632933,
#  'Loss/regularization_loss': 0.14951299,
#  'Loss/total_loss': 1.228726,
#  'learning_rate': 0.078346714}
# I0826 10:23:28.565387 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.51591974,
#  'Loss/localization_loss': 0.5632933,
#  'Loss/regularization_loss': 0.14951299,
#  'Loss/total_loss': 1.228726,
#  'learning_rate': 0.078346714}
# INFO:tensorflow:Step 5600 per-step time 0.192s
# I0826 10:23:47.760656 140418409645952 model_lib_v2.py:700] Step 5600 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.58502024,
#  'Loss/localization_loss': 0.76534724,
#  'Loss/regularization_loss': 0.14936845,
#  'Loss/total_loss': 1.499736,
#  'learning_rate': 0.07827295}
# I0826 10:23:47.761102 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.58502024,
#  'Loss/localization_loss': 0.76534724,
#  'Loss/regularization_loss': 0.14936845,
#  'Loss/total_loss': 1.499736,
#  'learning_rate': 0.07827295}
# INFO:tensorflow:Step 5700 per-step time 0.192s
# I0826 10:24:07.005742 140418409645952 model_lib_v2.py:700] Step 5700 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.4507495,
#  'Loss/localization_loss': 0.52485806,
#  'Loss/regularization_loss': 0.14909944,
#  'Loss/total_loss': 1.124707,
#  'learning_rate': 0.07819763}
# I0826 10:24:07.006209 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.4507495,
#  'Loss/localization_loss': 0.52485806,
#  'Loss/regularization_loss': 0.14909944,
#  'Loss/total_loss': 1.124707,
#  'learning_rate': 0.07819763}
# INFO:tensorflow:Step 5800 per-step time 0.193s
# I0826 10:24:26.320682 140418409645952 model_lib_v2.py:700] Step 5800 per-step time 0.193s
# INFO:tensorflow:{'Loss/classification_loss': 0.4406149,
#  'Loss/localization_loss': 0.60750055,
#  'Loss/regularization_loss': 0.14868835,
#  'Loss/total_loss': 1.1968038,
#  'learning_rate': 0.07812072}
# I0826 10:24:26.321071 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.4406149,
#  'Loss/localization_loss': 0.60750055,
#  'Loss/regularization_loss': 0.14868835,
#  'Loss/total_loss': 1.1968038,
#  'learning_rate': 0.07812072}
# INFO:tensorflow:Step 5900 per-step time 0.192s
# I0826 10:24:45.491581 140418409645952 model_lib_v2.py:700] Step 5900 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.49671227,
#  'Loss/localization_loss': 0.63346016,
#  'Loss/regularization_loss': 0.1485077,
#  'Loss/total_loss': 1.2786802,
#  'learning_rate': 0.078042254}
# I0826 10:24:45.491952 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.49671227,
#  'Loss/localization_loss': 0.63346016,
#  'Loss/regularization_loss': 0.1485077,
#  'Loss/total_loss': 1.2786802,
#  'learning_rate': 0.078042254}
# INFO:tensorflow:Step 6000 per-step time 0.192s
# I0826 10:25:04.729274 140418409645952 model_lib_v2.py:700] Step 6000 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.37613577,
#  'Loss/localization_loss': 0.45455286,
#  'Loss/regularization_loss': 0.14840166,
#  'Loss/total_loss': 0.9790903,
#  'learning_rate': 0.07796223}
# I0826 10:25:04.729647 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.37613577,
#  'Loss/localization_loss': 0.45455286,
#  'Loss/regularization_loss': 0.14840166,
#  'Loss/total_loss': 0.9790903,
#  'learning_rate': 0.07796223}
# INFO:tensorflow:Step 6100 per-step time 0.198s
# I0826 10:25:24.574287 140418409645952 model_lib_v2.py:700] Step 6100 per-step time 0.198s
# INFO:tensorflow:{'Loss/classification_loss': 0.7372144,
#  'Loss/localization_loss': 0.69896156,
#  'Loss/regularization_loss': 0.14808859,
#  'Loss/total_loss': 1.5842645,
#  'learning_rate': 0.077880636}
# I0826 10:25:24.574658 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.7372144,
#  'Loss/localization_loss': 0.69896156,
#  'Loss/regularization_loss': 0.14808859,
#  'Loss/total_loss': 1.5842645,
#  'learning_rate': 0.077880636}
# INFO:tensorflow:Step 6200 per-step time 0.193s
# I0826 10:25:43.922477 140418409645952 model_lib_v2.py:700] Step 6200 per-step time 0.193s
# INFO:tensorflow:{'Loss/classification_loss': 0.5080215,
#  'Loss/localization_loss': 0.44179815,
#  'Loss/regularization_loss': 0.14789705,
#  'Loss/total_loss': 1.0977167,
#  'learning_rate': 0.07779749}
# I0826 10:25:43.922870 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.5080215,
# ...
# INFO:tensorflow:{'Loss/classification_loss': 0.40957603,
#  'Loss/localization_loss': 0.59604317,
#  'Loss/regularization_loss': 0.14453144,
#  'Loss/total_loss': 1.1501507,
#  'learning_rate': 0.07678111}
# I0826 10:29:15.910074 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.40957603,
#  'Loss/localization_loss': 0.59604317,
#  'Loss/regularization_loss': 0.14453144,
#  'Loss/total_loss': 1.1501507,
#  'learning_rate': 0.07678111}
# INFO:tensorflow:Step 7400 per-step time 0.192s
# I0826 10:29:35.075805 140418409645952 model_lib_v2.py:700] Step 7400 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.3343943,
#  'Loss/localization_loss': 0.49734586,
#  'Loss/regularization_loss': 0.14421627,
#  'Loss/total_loss': 0.97595644,
#  'learning_rate': 0.076679565}
# I0826 10:29:35.076131 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.3343943,
#  'Loss/localization_loss': 0.49734586,
#  'Loss/regularization_loss': 0.14421627,
#  'Loss/total_loss': 0.97595644,
#  'learning_rate': 0.076679565}
# INFO:tensorflow:Step 7500 per-step time 0.192s
# I0826 10:29:54.267997 140418409645952 model_lib_v2.py:700] Step 7500 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.5265572,
#  'Loss/localization_loss': 0.46055514,
#  'Loss/regularization_loss': 0.14395255,
#  'Loss/total_loss': 1.1310649,
#  'learning_rate': 0.0765765}
# I0826 10:29:54.268348 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.5265572,
#  'Loss/localization_loss': 0.46055514,
#  'Loss/regularization_loss': 0.14395255,
#  'Loss/total_loss': 1.1310649,
#  'learning_rate': 0.0765765}
# INFO:tensorflow:Step 7600 per-step time 0.191s
# I0826 10:30:13.352796 140418409645952 model_lib_v2.py:700] Step 7600 per-step time 0.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.5034991,
#  'Loss/localization_loss': 0.4312728,
#  'Loss/regularization_loss': 0.14365281,
#  'Loss/total_loss': 1.0784247,
#  'learning_rate': 0.07647194}
# I0826 10:30:13.353180 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.5034991,
#  'Loss/localization_loss': 0.4312728,
#  'Loss/regularization_loss': 0.14365281,
#  'Loss/total_loss': 1.0784247,
#  'learning_rate': 0.07647194}
# INFO:tensorflow:Step 7700 per-step time 0.193s
# I0826 10:30:32.622245 140418409645952 model_lib_v2.py:700] Step 7700 per-step time 0.193s
# INFO:tensorflow:{'Loss/classification_loss': 0.37679985,
#  'Loss/localization_loss': 0.43874595,
#  'Loss/regularization_loss': 0.14361681,
#  'Loss/total_loss': 0.9591626,
#  'learning_rate': 0.07636588}
# I0826 10:30:32.622665 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.37679985,
#  'Loss/localization_loss': 0.43874595,
#  'Loss/regularization_loss': 0.14361681,
#  'Loss/total_loss': 0.9591626,
#  'learning_rate': 0.07636588}
# INFO:tensorflow:Step 7800 per-step time 0.192s
# I0826 10:30:51.803087 140418409645952 model_lib_v2.py:700] Step 7800 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.3454029,
#  'Loss/localization_loss': 0.36733127,
#  'Loss/regularization_loss': 0.14330868,
#  'Loss/total_loss': 0.85604286,
#  'learning_rate': 0.07625833}
# I0826 10:30:51.803493 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.3454029,
#  'Loss/localization_loss': 0.36733127,
#  'Loss/regularization_loss': 0.14330868,
#  'Loss/total_loss': 0.85604286,
#  'learning_rate': 0.07625833}
# INFO:tensorflow:Step 7900 per-step time 0.193s
# I0826 10:31:11.061221 140418409645952 model_lib_v2.py:700] Step 7900 per-step time 0.193s
# INFO:tensorflow:{'Loss/classification_loss': 0.43838894,
#  'Loss/localization_loss': 0.5659902,
#  'Loss/regularization_loss': 0.14291504,
#  'Loss/total_loss': 1.1472942,
#  'learning_rate': 0.07614928}
# I0826 10:31:11.061581 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.43838894,
#  'Loss/localization_loss': 0.5659902,
#  'Loss/regularization_loss': 0.14291504,
#  'Loss/total_loss': 1.1472942,
#  'learning_rate': 0.07614928}
# INFO:tensorflow:Step 8000 per-step time 0.193s
# I0826 10:31:30.382221 140418409645952 model_lib_v2.py:700] Step 8000 per-step time 0.193s
# INFO:tensorflow:{'Loss/classification_loss': 0.50792927,
#  'Loss/localization_loss': 0.69842154,
#  'Loss/regularization_loss': 0.14283715,
#  'Loss/total_loss': 1.349188,
#  'learning_rate': 0.07603875}
# I0826 10:31:30.382677 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.50792927,
#  'Loss/localization_loss': 0.69842154,
#  'Loss/regularization_loss': 0.14283715,
#  'Loss/total_loss': 1.349188,
#  'learning_rate': 0.07603875}
# INFO:tensorflow:Step 8100 per-step time 0.198s
# I0826 10:31:50.171826 140418409645952 model_lib_v2.py:700] Step 8100 per-step time 0.198s
# INFO:tensorflow:{'Loss/classification_loss': 0.24330166,
#  'Loss/localization_loss': 0.14518027,
#  'Loss/regularization_loss': 0.1424651,
#  'Loss/total_loss': 0.530947,
#  'learning_rate': 0.07592674}
# I0826 10:31:50.172265 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.24330166,
#  'Loss/localization_loss': 0.14518027,
#  'Loss/regularization_loss': 0.1424651,
#  'Loss/total_loss': 0.530947,
#  'learning_rate': 0.07592674}
# INFO:tensorflow:Step 8200 per-step time 0.194s
# I0826 10:32:09.552527 140418409645952 model_lib_v2.py:700] Step 8200 per-step time 0.194s
# INFO:tensorflow:{'Loss/classification_loss': 0.42629915,
#  'Loss/localization_loss': 0.4147519,
#  'Loss/regularization_loss': 0.14212921,
#  'Loss/total_loss': 0.9831803,
#  'learning_rate': 0.075813256}
# I0826 10:32:09.552992 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.42629915,
#  'Loss/localization_loss': 0.4147519,
#  'Loss/regularization_loss': 0.14212921,
#  'Loss/total_loss': 0.9831803,
#  'learning_rate': 0.075813256}
# INFO:tensorflow:Step 8300 per-step time 0.192s
# I0826 10:32:28.787765 140418409645952 model_lib_v2.py:700] Step 8300 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.44171777,
#  'Loss/localization_loss': 0.43020937,
#  'Loss/regularization_loss': 0.14187162,
#  'Loss/total_loss': 1.0137987,
#  'learning_rate': 0.07569829}
# I0826 10:32:28.788129 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.44171777,
#  'Loss/localization_loss': 0.43020937,
#  'Loss/regularization_loss': 0.14187162,
#  'Loss/total_loss': 1.0137987,
#  'learning_rate': 0.07569829}
# INFO:tensorflow:Step 8400 per-step time 0.192s
# I0826 10:32:47.960447 140418409645952 model_lib_v2.py:700] Step 8400 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.5917513,
#  'Loss/localization_loss': 0.6030216,
#  'Loss/regularization_loss': 0.14186041,
#  'Loss/total_loss': 1.3366333,
#  'learning_rate': 0.07558186}
# I0826 10:32:47.960848 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.5917513,
#  'Loss/localization_loss': 0.6030216,
#  'Loss/regularization_loss': 0.14186041,
#  'Loss/total_loss': 1.3366333,
#  'learning_rate': 0.07558186}
# INFO:tensorflow:Step 8500 per-step time 0.192s
# I0826 10:33:07.162688 140418409645952 model_lib_v2.py:700] Step 8500 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.49807382,
#  'Loss/localization_loss': 0.90491253,
#  'Loss/regularization_loss': 0.14169379,
#  'Loss/total_loss': 1.5446801,
#  'learning_rate': 0.07546397}
# I0826 10:33:07.163069 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.49807382,
#  'Loss/localization_loss': 0.90491253,
#  'Loss/regularization_loss': 0.14169379,
#  'Loss/total_loss': 1.5446801,
#  'learning_rate': 0.07546397}
# INFO:tensorflow:Step 8600 per-step time 0.192s
# I0826 10:33:26.383004 140418409645952 model_lib_v2.py:700] Step 8600 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.70063287,
#  'Loss/localization_loss': 0.73351145,
#  'Loss/regularization_loss': 0.14145628,
#  'Loss/total_loss': 1.5756005,
#  'learning_rate': 0.075344615}
# I0826 10:33:26.383390 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.70063287,
#  'Loss/localization_loss': 0.73351145,
#  'Loss/regularization_loss': 0.14145628,
#  'Loss/total_loss': 1.5756005,
#  'learning_rate': 0.075344615}
# INFO:tensorflow:Step 8700 per-step time 0.192s
# I0826 10:33:45.611144 140418409645952 model_lib_v2.py:700] Step 8700 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.42919588,
#  'Loss/localization_loss': 0.37168533,
#  'Loss/regularization_loss': 0.14112797,
#  'Loss/total_loss': 0.9420092,
#  'learning_rate': 0.07522382}
# I0826 10:33:45.611488 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.42919588,
#  'Loss/localization_loss': 0.37168533,
#  'Loss/regularization_loss': 0.14112797,
#  'Loss/total_loss': 0.9420092,
#  'learning_rate': 0.07522382}
# INFO:tensorflow:Step 8800 per-step time 0.193s
# I0826 10:34:04.911207 140418409645952 model_lib_v2.py:700] Step 8800 per-step time 0.193s
# INFO:tensorflow:{'Loss/classification_loss': 0.6865106,
#  'Loss/localization_loss': 0.6027116,
#  'Loss/regularization_loss': 0.14089984,
#  'Loss/total_loss': 1.4301221,
#  'learning_rate': 0.07510157}
# I0826 10:34:04.911565 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.6865106,
#  'Loss/localization_loss': 0.6027116,
#  'Loss/regularization_loss': 0.14089984,
#  'Loss/total_loss': 1.4301221,
#  'learning_rate': 0.07510157}
# INFO:tensorflow:Step 8900 per-step time 0.192s
# I0826 10:34:24.138162 140418409645952 model_lib_v2.py:700] Step 8900 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.3260251,
#  'Loss/localization_loss': 0.29262725,
#  'Loss/regularization_loss': 0.14076759,
#  'Loss/total_loss': 0.7594199,
#  'learning_rate': 0.074977875}
# I0826 10:34:24.138484 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.3260251,
#  'Loss/localization_loss': 0.29262725,
#  'Loss/regularization_loss': 0.14076759,
#  'Loss/total_loss': 0.7594199,
#  'learning_rate': 0.074977875}
# INFO:tensorflow:Step 9000 per-step time 0.192s
# I0826 10:34:43.351551 140418409645952 model_lib_v2.py:700] Step 9000 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.4700369,
#  'Loss/localization_loss': 0.4602027,
#  'Loss/regularization_loss': 0.14160496,
#  'Loss/total_loss': 1.0718446,
#  'learning_rate': 0.07485275}
# I0826 10:34:43.351952 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.4700369,
#  'Loss/localization_loss': 0.4602027,
#  'Loss/regularization_loss': 0.14160496,
#  'Loss/total_loss': 1.0718446,
#  'learning_rate': 0.07485275}
# INFO:tensorflow:Step 9100 per-step time 0.197s
# I0826 10:35:03.080345 140418409645952 model_lib_v2.py:700] Step 9100 per-step time 0.197s
# INFO:tensorflow:{'Loss/classification_loss': 0.36251292,
#  'Loss/localization_loss': 0.43337035,
#  'Loss/regularization_loss': 0.14126064,
#  'Loss/total_loss': 0.9371439,
#  'learning_rate': 0.07472619}
# I0826 10:35:03.080722 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.36251292,
#  'Loss/localization_loss': 0.43337035,
#  'Loss/regularization_loss': 0.14126064,
#  'Loss/total_loss': 0.9371439,
#  'learning_rate': 0.07472619}
# INFO:tensorflow:Step 9200 per-step time 0.192s
# I0826 10:35:22.264168 140418409645952 model_lib_v2.py:700] Step 9200 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.57011044,
#  'Loss/localization_loss': 0.77171373,
#  'Loss/regularization_loss': 0.14099315,
#  'Loss/total_loss': 1.4828173,
#  'learning_rate': 0.07459819}
# I0826 10:35:22.264581 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.57011044,
#  'Loss/localization_loss': 0.77171373,
#  'Loss/regularization_loss': 0.14099315,
#  'Loss/total_loss': 1.4828173,
#  'learning_rate': 0.07459819}
# INFO:tensorflow:Step 9300 per-step time 0.191s
# I0826 10:35:41.353958 140418409645952 model_lib_v2.py:700] Step 9300 per-step time 0.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.5346399,
#  'Loss/localization_loss': 0.690615,
#  'Loss/regularization_loss': 0.14072746,
#  'Loss/total_loss': 1.3659823,
#  'learning_rate': 0.074468784}
# I0826 10:35:41.354366 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.5346399,
#  'Loss/localization_loss': 0.690615,
#  'Loss/regularization_loss': 0.14072746,
#  'Loss/total_loss': 1.3659823,
#  'learning_rate': 0.074468784}
# INFO:tensorflow:Step 9400 per-step time 0.192s
# I0826 10:36:00.590386 140418409645952 model_lib_v2.py:700] Step 9400 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.3894266,
#  'Loss/localization_loss': 0.5150744,
#  'Loss/regularization_loss': 0.14039609,
#  'Loss/total_loss': 1.0448971,
#  'learning_rate': 0.074337944}
# I0826 10:36:00.590794 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.3894266,
#  'Loss/localization_loss': 0.5150744,
#  'Loss/regularization_loss': 0.14039609,
#  'Loss/total_loss': 1.0448971,
#  'learning_rate': 0.074337944}
# INFO:tensorflow:Step 9500 per-step time 0.193s
# I0826 10:36:19.923416 140418409645952 model_lib_v2.py:700] Step 9500 per-step time 0.193s
# INFO:tensorflow:{'Loss/classification_loss': 0.526278,
#  'Loss/localization_loss': 0.51000965,
#  'Loss/regularization_loss': 0.14032789,
#  'Loss/total_loss': 1.1766156,
#  'learning_rate': 0.074205704}
# I0826 10:36:19.923775 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.526278,
#  'Loss/localization_loss': 0.51000965,
#  'Loss/regularization_loss': 0.14032789,
#  'Loss/total_loss': 1.1766156,
#  'learning_rate': 0.074205704}
# INFO:tensorflow:Step 9600 per-step time 0.192s
# I0826 10:36:39.126412 140418409645952 model_lib_v2.py:700] Step 9600 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.33946183,
#  'Loss/localization_loss': 0.46272722,
#  'Loss/regularization_loss': 0.14032136,
#  'Loss/total_loss': 0.9425104,
#  'learning_rate': 0.07407206}
# I0826 10:36:39.126779 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.33946183,
#  'Loss/localization_loss': 0.46272722,
#  'Loss/regularization_loss': 0.14032136,
#  'Loss/total_loss': 0.9425104,
#  'learning_rate': 0.07407206}
# INFO:tensorflow:Step 9700 per-step time 0.192s
# I0826 10:36:58.371985 140418409645952 model_lib_v2.py:700] Step 9700 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.37061313,
#  'Loss/localization_loss': 0.32390687,
#  'Loss/regularization_loss': 0.14008904,
#  'Loss/total_loss': 0.83460903,
#  'learning_rate': 0.073937014}
# I0826 10:36:58.372359 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.37061313,
#  'Loss/localization_loss': 0.32390687,
#  'Loss/regularization_loss': 0.14008904,
#  'Loss/total_loss': 0.83460903,
#  'learning_rate': 0.073937014}
# INFO:tensorflow:Step 9800 per-step time 0.192s
# I0826 10:37:17.564929 140418409645952 model_lib_v2.py:700] Step 9800 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.4762016,
#  'Loss/localization_loss': 0.44475824,
#  'Loss/regularization_loss': 0.13975999,
#  'Loss/total_loss': 1.0607198,
#  'learning_rate': 0.07380057}
# I0826 10:37:17.565305 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.4762016,
#  'Loss/localization_loss': 0.44475824,
#  'Loss/regularization_loss': 0.13975999,
#  'Loss/total_loss': 1.0607198,
#  'learning_rate': 0.07380057}
# INFO:tensorflow:Step 9900 per-step time 0.194s
# I0826 10:37:36.930301 140418409645952 model_lib_v2.py:700] Step 9900 per-step time 0.194s
# INFO:tensorflow:{'Loss/classification_loss': 0.32050684,
#  'Loss/localization_loss': 0.340055,
#  'Loss/regularization_loss': 0.1395488,
#  'Loss/total_loss': 0.8001106,
#  'learning_rate': 0.073662736}
# I0826 10:37:36.930664 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.32050684,
#  'Loss/localization_loss': 0.340055,
#  'Loss/regularization_loss': 0.1395488,
#  'Loss/total_loss': 0.8001106,
#  'learning_rate': 0.073662736}
# INFO:tensorflow:Step 10000 per-step time 0.191s
# I0826 10:37:56.002828 140418409645952 model_lib_v2.py:700] Step 10000 per-step time 0.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.3784183,
#  'Loss/localization_loss': 0.43183544,
#  'Loss/regularization_loss': 0.13934606,
#  'Loss/total_loss': 0.9495998,
#  'learning_rate': 0.07352352}
# I0826 10:37:56.003272 140418409645952 model_lib_v2.py:701] {'Loss/classification_loss': 0.3784183,
#  'Loss/localization_loss': 0.43183544,
#  'Loss/regularization_loss': 0.13934606,
#  'Loss/total_loss': 0.9495998,
#  'learning_rate': 0.07352352}

# %% [markdown]
# # 7. Evaluate the Model
# ###### *Hoang-26June2021: Don't run because still don't understand this code.*

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --checkpoint_dir={}".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'])

# %%
print(command)
# Out:
# python Tensorflow/models/research/object_detection/model_main_tf2.py --model_dir=Tensorflow/workspace/models/my_ssd_mobnet --pipeline_config_path=Tensorflow/workspace/models/my_ssd_mobnet/pipeline.config --checkpoint_dir=Tensorflow/workspace/models/my_ssd_mobnet

# %%
# !{command
model_lib_v2.py:1010] 	+ Loss/classification_loss: 0.593757
# INFO:tensorflow:	+ Loss/regularization_loss: 0.139346
# I0826 11:06:45.466325 140304433162112 model_lib_v2.py:1010] 	+ Loss/regularization_loss: 0.139346
# INFO:tensorflow:	+ Loss/total_loss: 1.461183
# I0826 11:06:45.467546 140304433162112 model_lib_v2.py:1010] 	+ Loss/total_loss: 1.461183
# INFO:tensorflow:Waiting for new checkpoint at Tensorflow/workspace/models/my_ssd_mobnet
# I0826 11:10:12.645569 140304433162112 checkpoint_utils.py:140] Waiting for new checkpoint at Tensorflow/workspace/models/my_ssd_mobnet
# Traceback (most recent call last):
#   File "Tensorflow/models/research/object_detection/model_main_tf2.py", line 115, in <module>
#     tf.compat.v1.app.run()
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/platform/app.py", line 40, in run
#     _run(main=main, argv=argv, flags_parser=_parse_flags_tolerate_undef)
#   File "/usr/local/lib/python3.7/dist-packages/absl/app.py", line 303, in run
#     _run_main(main, args)
#   File "/usr/local/lib/python3.7/dist-packages/absl/app.py", line 251, in _run_main
#     sys.exit(main(argv))
#   File "Tensorflow/models/research/object_detection/model_main_tf2.py", line 90, in main
#     wait_interval=300, timeout=FLAGS.eval_timeout)
#   File "/usr/local/lib/python3.7/dist-packages/object_detection/model_lib_v2.py", line 1129, in eval_continuously
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/training/checkpoint_utils.py", line 199, in checkpoints_iterator
#     checkpoint_dir, checkpoint_path, timeout=timeout)
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/training/checkpoint_utils.py", line 147, in wait_for_new_checkpoint
#     time.sleep(seconds_to_sleep)
# KeyboardInterrupt

# %% [markdown]
# # 8. Load Train Model From Checkpoint

# %%
import os
import tensorflow as tf
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder
from object_detection.utils import config_util

# %%
print(tf.__version__)
# Out:
# 2.6.0

# %%
# Prevent GPU complete consumption
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try: 
        tf.config.experimental.set_virtual_device_configuration(
            gpus[0], [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=5120)])
    except RunTimeError as e:
        print(e)

# %%
# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])
detection_model = model_builder.build(model_config=configs['model'], is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
ckpt.restore(os.path.join(paths['CHECKPOINT_PATH'], 'ckpt-11')).expect_partial()

@tf.function
def detect_fn(image):
    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)
    return detections

# %% [markdown]
# # 9. Detect from an Image

# %%
import cv2 
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
category_index = label_map_util.create_category_index_from_labelmap(files['LABELMAP'])

# %%
IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'test', '000000548824.jpg')

# %%
img = cv2.imread(IMAGE_PATH)
image_np = np.array(img)

input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)

detections = detect_fn(input_tensor)

num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
              for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

label_id_offset = 1
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
            image_np_with_detections,
            detections['detection_boxes'],
            detections['detection_classes']+label_id_offset,
            detections['detection_scores'],
            category_index,
            use_normalized_coordinates=True,
            max_boxes_to_draw=5,
            min_score_thresh=.1,
            agnostic_mode=False)

plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# # 10. Freezing the Graph

# %%
FREEZE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'exporter_main_v2.py ')

# %%
command = "python {} --input_type=image_tensor --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(FREEZE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['OUTPUT_PATH'])

# %%
print(command)
# Out:
# python Tensorflow/models/research/object_detection/exporter_main_v2.py  --input_type=image_tensor --pipeline_config_path=Tensorflow/workspace/models/my_ssd_mobnet/pipeline.config --trained_checkpoint_dir=Tensorflow/workspace/models/my_ssd_mobnet --output_directory=Tensorflow/workspace/models/my_ssd_mobnet/export

# %%
# !{command}
# Out:
# 2021-08-26 10:58:33.439402: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-26 10:58:33.456514: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-26 10:58:33.457327: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-26 10:58:33.467447: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-26 10:58:33.468201: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-26 10:58:33.468879: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-26 10:58:33.947824: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-26 10:58:33.948610: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-26 10:58:33.949380: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-26 10:58:33.950037: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-08-26 10:58:33.950118: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8918 MB memory:  -> device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:463: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W0826 10:58:34.133125 139760637364096 deprecation.py:616] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:463: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f1c20089550>, because it is not built.
# W0826 10:58:53.243971 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f1c20089550>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f1be00c3b10>, because it is not built.
# W0826 10:58:53.529925 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f1be00c3b10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1bdf6e66d0>, because it is not built.
# W0826 10:58:53.530261 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1bdf6e66d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdffc65d0>, because it is not built.
# W0826 10:58:53.530429 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdffc65d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f1bdf6e6f90>, because it is not built.
# W0826 10:58:53.530578 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f1bdf6e6f90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1bdf6e6ed0>, because it is not built.
# W0826 10:58:53.530814 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1bdf6e6ed0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdf6c5890>, because it is not built.
# W0826 10:58:53.530996 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdf6c5890>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f1bdf731090>, because it is not built.
# W0826 10:58:53.531149 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f1bdf731090>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1bdf6c5fd0>, because it is not built.
# W0826 10:58:53.531292 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1bdf6c5fd0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdf7016d0>, because it is not built.
# W0826 10:58:53.531433 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdf7016d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f1bdf77d850>, because it is not built.
# W0826 10:58:53.531578 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f1bdf77d850>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1bdf7017d0>, because it is not built.
# W0826 10:58:53.531776 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1bdf7017d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdf701b10>, because it is not built.
# W0826 10:58:53.531919 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdf701b10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1be00c8850>, because it is not built.
# W0826 10:58:53.532072 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1be00c8850>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdf675c50>, because it is not built.
# W0826 10:58:53.532212 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdf675c50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1bdf7f8e90>, because it is not built.
# W0826 10:58:53.532355 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1bdf7f8e90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdf7f8750>, because it is not built.
# W0826 10:58:53.532498 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdf7f8750>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1bdf72e890>, because it is not built.
# W0826 10:58:53.532640 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1bdf72e890>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdf5d53d0>, because it is not built.
# W0826 10:58:53.532836 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdf5d53d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1bdf5d5dd0>, because it is not built.
# W0826 10:58:53.533003 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1bdf5d5dd0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdf764210>, because it is not built.
# W0826 10:58:53.533221 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdf764210>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1be00c8890>, because it is not built.
# W0826 10:58:53.533372 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1be00c8890>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdf7053d0>, because it is not built.
# W0826 10:58:53.533518 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdf7053d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1bdf70bc50>, because it is not built.
# W0826 10:58:53.533660 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1bdf70bc50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdf6fab10>, because it is not built.
# W0826 10:58:53.533825 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdf6fab10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1bdfd41610>, because it is not built.
# W0826 10:58:53.533970 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1bdfd41610>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdf6fa850>, because it is not built.
# W0826 10:58:53.534128 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdf6fa850>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1bdf6fa150>, because it is not built.
# W0826 10:58:53.534272 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1bdf6fa150>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdf58c290>, because it is not built.
# W0826 10:58:53.534415 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdf58c290>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1bdf70b9d0>, because it is not built.
# W0826 10:58:53.534557 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1bdf70b9d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdf574710>, because it is not built.
# W0826 10:58:53.534722 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdf574710>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1bdf764990>, because it is not built.
# W0826 10:58:53.534857 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1bdf764990>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdf610790>, because it is not built.
# W0826 10:58:53.534996 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdf610790>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1bdf610b90>, because it is not built.
# W0826 10:58:53.535166 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1bdf610b90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdf610290>, because it is not built.
# W0826 10:58:53.535341 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdf610290>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1bdf8c4110>, because it is not built.
# W0826 10:58:53.535515 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1bdf8c4110>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdf56b550>, because it is not built.
# W0826 10:58:53.535688 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdf56b550>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1be00c88d0>, because it is not built.
# W0826 10:58:53.535827 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1be00c88d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdf5802d0>, because it is not built.
# W0826 10:58:53.535974 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdf5802d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1bdfeaced0>, because it is not built.
# W0826 10:58:53.536134 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1bdfeaced0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdf580a90>, because it is not built.
# W0826 10:58:53.536279 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdf580a90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1bdf75f210>, because it is not built.
# W0826 10:58:53.536436 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1bdf75f210>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdf580bd0>, because it is not built.
# W0826 10:58:53.536576 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdf580bd0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1bdf73c090>, because it is not built.
# W0826 10:58:53.536728 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f1bdf73c090>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdf73c450>, because it is not built.
# W0826 10:58:53.536907 139760637364096 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x7f1bdf73c450>, because it is not built.
# 2021-08-26 10:59:05.931285: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# W0826 10:59:28.506808 139760637364096 save.py:254] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_fn while saving (showing 5 of 260). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Tensorflow/workspace/models/my_ssd_mobnet/export/saved_model/assets
# I0826 10:59:34.353942 139760637364096 builder_impl.py:781] Assets written to: Tensorflow/workspace/models/my_ssd_mobnet/export/saved_model/assets
# INFO:tensorflow:Writing pipeline config file to Tensorflow/workspace/models/my_ssd_mobnet/export/pipeline.config
# I0826 10:59:35.182453 139760637364096 config_util.py:254] Writing pipeline config file to Tensorflow/workspace/models/my_ssd_mobnet/export/pipeline.config

# %% [markdown]
# # 11. Conversion to TFJS
# ###### *Hoang-26June2021: Don't run because still don't understand this code.*

# %%
# !pip install tensorflowjs

# %%
command = "tensorflowjs_converter --input_format=tf_saved_model --output_node_names='detection_boxes,detection_classes,detection_features,detection_multiclass_scores,detection_scores,num_detections,raw_detection_boxes,raw_detection_scores' --output_format=tfjs_graph_model --signature_name=serving_default {} {}".format(os.path.join(paths['OUTPUT_PATH'], 'saved_model'), paths['TFJS_PATH'])

# %%
print(command)

# %%
# !{command}

# %%
# Test Code: https://github.com/nicknochnack/RealTimeSignLanguageDetectionwithTFJS

# %% [markdown]
# # 12. Conversion to TFLite
# ###### *Hoang-26June2021: Don't run because still don't understand this code.*

# %%
TFLITE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'export_tflite_graph_tf2.py ')

# %%
command = "python {} --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(TFLITE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['TFLITE_PATH'])

# %%
print(command)

# %%
# !{command}

# %%
FROZEN_TFLITE_PATH = os.path.join(paths['TFLITE_PATH'], 'saved_model')
TFLITE_MODEL = os.path.join(paths['TFLITE_PATH'], 'saved_model', 'detect.tflite')

# %%
command = "tflite_convert \
--saved_model_dir={} \
--output_file={} \
--input_shapes=1,300,300,3 \
--input_arrays=normalized_input_image_tensor \
--output_arrays='TFLite_Detection_PostProcess','TFLite_Detection_PostProcess:1','TFLite_Detection_PostProcess:2','TFLite_Detection_PostProcess:3' \
--inference_type=FLOAT \
--allow_custom_ops".format(FROZEN_TFLITE_PATH, TFLITE_MODEL, )

# %%
print(command)

# %%
# !{command}

# %% [markdown]
# # 13. Zip and Export Models

# %%
import datetime
import pytz
my_date = datetime.datetime.now(pytz.timezone('Asia/Bangkok'))
print(my_date)
# Out:
# 2021-08-26 18:41:23.245452+07:00

# %%
dt = str(my_date)
dt_year = dt[0:4]
dt_month = dt[5:7]
dt_day = dt[8:10]
dt_hr = dt[11:13]
dt_min = dt[14:16]
dt_sec = dt[17:19]
dt_full = "{}{}{}_{}{}{}".format(dt_year,dt_month,dt_day,dt_hr,dt_min,dt_sec)
print(dt_year,dt_month,dt_day,dt_hr,dt_min,dt_sec)
print(dt_full)
# Out:
# 2021 08 26 18 41 23
# 20210826_184123

# %%
link_model = "/content/drive/MyDrive/model_{}.zip".format(dt_full)
print(link_model)
# Out:
# /content/drive/MyDrive/model_20210826_184123.zip

# %%
# !zip -r {link_model} {paths['CHECKPOINT_PATH']}
# Out:
#   adding: Tensorflow/workspace/models/my_ssd_mobnet/ (stored 0%)
#   adding: Tensorflow/workspace/models/my_ssd_mobnet/ckpt-11.index (deflated 82%)
#   adding: Tensorflow/workspace/models/my_ssd_mobnet/ckpt-10.data-00000-of-00001 (deflated 7%)
#   adding: Tensorflow/workspace/models/my_ssd_mobnet/ckpt-9.index (deflated 82%)
#   adding: Tensorflow/workspace/models/my_ssd_mobnet/pipeline.config (deflated 69%)
#   adding: Tensorflow/workspace/models/my_ssd_mobnet/ckpt-9.data-00000-of-00001 (deflated 7%)
#   adding: Tensorflow/workspace/models/my_ssd_mobnet/tfliteexport/ (stored 0%)
#   adding: Tensorflow/workspace/models/my_ssd_mobnet/train/ (stored 0%)
#   adding: Tensorflow/workspace/models/my_ssd_mobnet/train/events.out.tfevents.1629972249.48906c11a157.812.0.v2 (deflated 0%)
#   adding: Tensorflow/workspace/models/my_ssd_mobnet/ckpt-11.data-00000-of-00001 (deflated 7%)
#   adding: Tensorflow/workspace/models/my_ssd_mobnet/checkpoint (deflated 76%)
#   adding: Tensorflow/workspace/models/my_ssd_mobnet/ckpt-10.index (deflated 82%)
#   adding: Tensorflow/workspace/models/my_ssd_mobnet/ckpt-6.data-00000-of-00001 (deflated 7%)
#   adding: Tensorflow/workspace/models/my_ssd_mobnet/ckpt-6.index (deflated 82%)
#   adding: Tensorflow/workspace/models/my_ssd_mobnet/tfjsexport/ (stored 0%)
#   adding: Tensorflow/workspace/models/my_ssd_mobnet/ckpt-5.index (deflated 82%)
#   adding: Tensorflow/workspace/models/my_ssd_mobnet/ckpt-8.index (deflated 82%)
#   adding: Tensorflow/workspace/models/my_ssd_mobnet/ckpt-7.data-00000-of-00001 (deflated 7%)
#   adding: Tensorflow/workspace/models/my_ssd_mobnet/eval/ (stored 0%)
#   adding: Tensorflow/workspace/models/my_ssd_mobnet/eval/events.out.tfevents.1629975912.48906c11a157.1386.0.v2 (deflated 2%)
#   adding: Tensorflow/workspace/models/my_ssd_mobnet/ckpt-5.data-00000-of-00001 (deflated 7%)
#   adding: Tensorflow/workspace/models/my_ssd_mobnet/ckpt-7.index (deflated 82%)
#   adding: Tensorflow/workspace/models/my_ssd_mobnet/export/ (stored 0%)
#   adding: Tensorflow/workspace/models/my_ssd_mobnet/export/pipeline.config (deflated 69%)
#   adding: Tensorflow/workspace/models/my_ssd_mobnet/export/checkpoint/ (stored 0%)
#   adding: Tensorflow/workspace/models/my_ssd_mobnet/export/checkpoint/ckpt-0.data-00000-of-00001 (deflated 8%)
#   adding: Tensorflow/workspace/models/my_ssd_mobnet/export/checkpoint/checkpoint (deflated 41%)
#   adding: Tensorflow/workspace/models/my_ssd_mobnet/export/checkpoint/ckpt-0.index (deflated 80%)
#   adding: Tensorflow/workspace/models/my_ssd_mobnet/export/saved_model/ (stored 0%)
#   adding: Tensorflow/workspace/models/my_ssd_mobnet/export/saved_model/variables/ (stored 0%)
#   adding: Tensorflow/workspace/models/my_ssd_mobnet/export/saved_model/variables/variables.index (deflated 77%)
#   adding: Tensorflow/workspace/models/my_ssd_mobnet/export/saved_model/variables/variables.data-00000-of-00001 (deflated 8%)
#   adding: Tensorflow/workspace/models/my_ssd_mobnet/export/saved_model/assets/ (stored 0%)
#   adding: Tensorflow/workspace/models/my_ssd_mobnet/export/saved_model/saved_model.pb (deflated 92%)
#   adding: Tensorflow/workspace/models/my_ssd_mobnet/ckpt-8.data-00000-of-00001 (deflated 7%)
